# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1W2XxFgXVonIBWhYHiypchGWh2TWvhs-Y?usp=sharing)

# %% [markdown]
# <img width="200"/>
#
# ![INNOVACION.png](data:image/png;base64,...)

# %% [markdown]
# # Taller ***Programación ConCiencia***
# Realizado por la Colectiva FEMCEN
#
# ¿Quieres saber más sobre la colectiva y nuestras actividades?  [Presiona acá](https://linktr.ee/colectivafemcen)

# %% [markdown]
# ## ***Contenido de este taller***
# #### **1.** *Introducción a Python*
# #### **2.** *Análisis de datos con Python*
# #### **3.** *Manos a la obra*
# #### **4.** *Algunos proyectos y referencias adicionales*

# %% [markdown]
# ## ***1. Introducción a Python***

# %% [markdown]
# **El primer programa que puedes crear: Imprimir en pantalla**
#
#
# [¿Por qué "Hola, mundo!"?](https://hipertextual.com/2016/01/hello-world-origen)

# %%
print("Hello, World!")   #las palabras deben estar siempre entre comillas dobles (" ") o simples (' ') 
#print("Mi nombre es:... y este es mi primer código")
# Out:
# Hello, World!

# %%
x = input(print("Ingresa un mensaje")) #La función input() permite al usuario ingresar datos
# Out:
# Ingresa un mensaje
# ¡Hola!

# %%
print("Tu mensaje es:", x)
# Out:
# Tu mensaje es: ¡Hola!

# %%
y = input(print("Ingresa tu nombre"))
# Out:
# Ingresa tu nombre
# FEMCEN

# %%
print("Hola",y, ', ¿cómo estás?')
# Out:
# Hola FEMCEN , ¿cómo estás?

# %% [markdown]
# ***Asignación de variables y operaciones***

# %%
a = 3
b = 2

# %%
print("La suma de las variables es", a+b)
# Out:
# La suma de las variables es 5

# %%
print("La resta de las variables es", a-b)
# Out:
# La resta de las variables es 1

# %%
print("La multiplicación de las variables es", a*b)
# Out:
# La multiplicación de las variables es 6

# %%
saludo = "Hola"
nombre = input("Ingresa tu nombre ")
#print(type(nombre))
#print(nombre[5:])
# Out:
# Ingresa tu nombre Valentina

# %%
print(saludo + " " + nombre)
print("¿Sabías que puedo realizar operaciones? \n ", "Para realizar una suma presiona 1, para realizar una resta presiona 2")
operacion=input()
a=input("Ingresa los valores que quieres operar \n")
b=input()
# Out:
# Hola Valentina
# ¿Sabías que puedo realizar operaciones?
#   Para realizar una suma presiona 1, para realizar una resta presiona 2
# 1
# Ingresa los valores que quieres operar
# 2
# 3

# %%
if operacion == '1':
  print("La suma de ", a , "+", b ,"es ", a+b)
#print(type(b))
# Out:
# La suma de  2 + 3 es  23

# %%
a=int(a)
b=int(b)
if operacion == '1':
  print("La suma de ", a , "+", b ,"es", a+b)
elif operacion == '2':
  print("La resta de ", a , "-", b ,"es", a-b)
# Out:
# La suma de  2 + 3 es 5

# %% [markdown]
# **"¡Pregunte por lo que no vea...!"**
#
# Python tiene una cantidad enorme de funciones, pero a veces requerimos funciones o métodos adiconales. Para eso se desarrollan de manera independiente diferentes librerías, así que cada vez que requieras algún tipo de solución consulta las diferentes librerías que exiten en Python, seguramente existe una que pueda ayudarte.
#
# Entre las librerías más comunes están **Matplotlib**, **Numpy**, **Pandas** y **Scipy**

# %%
# Esta es la manera tradicional de importar librerias
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# No todas las librerías son muy convencinales pero con seguridad exiten unas muy útiles

# %%
from googletrans import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-327f13001f1d> in <module>()
# ----> 1 from googletrans import *
#
# ModuleNotFoundError: No module named 'googletrans'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# En caso de que sean librerías no muy comunes lo más probable es que Colab no tenga la librería instalada, la buena noticia es que no tienes que instalar nada en tu computador pues puedes hacerlo directamente en este notebook

# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 17.4 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.9 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17415 sha256=8e2c73cc39f21fb6e53a84117784c7f192472dd473225bcfebd2e5066cd70e74
#   Stored in directory: /root/.cache/pip/wheels/43/34/00/4fe71786ea6d12314b29037620c36d857e5d104ac2748bf82a
# Successfully built googletrans
# ...

# %%
from googletrans import Translator

# %%
translator = Translator()
translation = translator.translate("Der Himmel ist blau und ich mag Bananen", dest='en')
print(translation.text)
# Out:
# The sky is blue and I like bananas

# %% [markdown]
# ¿Cómo lo traducirían a español?

# %% [markdown]
# # **2.** ***Análisis de datos con Python***
#
# ### 1. *Base de datos de Estados Unidos participación de mujeres en áreas STEM*
#
# Para más información: [Catalyst](https://www.catalyst.org/research/women-in-science-technology-engineering-and-mathematics-stem/)
# ### 2.   *Base de datos Colombiana*
#
# Para más información: [Observatorio Colombiano de Ciencia y Tecnología](https://ocyt.org.co/)

# %%
# Importar Librerías

# %% [markdown]
# ## **2.1** **Base de datos de Estados Unidos**

# %%
url="https://raw.githubusercontent.com/colectivafemcen/Programando-ConCiencia/main/Education.csv"
data_Ed=pd.read_csv(url)

# %%
data_Ed
# Out:
#                                           Unnamed: 0  ...  PhDs
# 0                 Biological and Biomedical Sciences  ...  53.4
# 1                         Mathematics and Statistics  ...  28.0
# 2         Physical Sciences and Science Technologies  ...  34.1
# 3           Engineering and Engineering Technologies  ...  24.5
# 4  Computer and Information Sciences and Support ...  ...  21.7
# 5                                    All STEM Fields  ...  34.6
#
# [6 rows x 4 columns]

# %%
url="https://raw.githubusercontent.com/colectivafemcen/Programando-ConCiencia/main/Labor%20Force.csv"
data_Em=pd.read_csv(url)

# %%
data_Em
# Out:
#                                           Unnamed: 0  Women's Employment
# 0     Life, Physical, and Social Science Occupations                49.4
# 1                              Biological Scientists                47.7
# 2              Computer and Mathematical Occupations                25.8
# 3  Software Developers, Applications and Systems ...                18.7
# 4           Architecture and Engineering Occupations                15.7
# 5                                    Civil Engineers                13.9

# %% [markdown]
# Documentación: Graficos de barras horizontales [matplotlib.pyplot.barh](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html), graficos de barras [matplotlib.pyplot.bar](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar) y graficación en general

# %%
data_Em.plot.barh()
#data_Em.plot.barh(x='Unnamed: 0')
#data_Em.plot.barh(figsize=(12,8))
#data_Em.plot.barh(color='r')
#plt.xlabel("Porcentaje de mujeres laborando")
#plt.ylabel(" ")
#plt.title("Porcentaje de mujeres laborando por áreas STEM")
# Out:
# Text(0.5, 1.0, 'Porcentaje de mujeres laborando por áreas STEM')

# %%
data_Ed.plot.barh(x='Unnamed: 0')
plt.xlabel("Porcentaje de mujeres")
plt.ylabel(" ")
#data_Ed.plot.barh(x='Unnamed: 0',figsize=(12,8), width=0.7)
#plt.grid(linestyle='-.')
#plt.legend(prop={'size': 16})
# Out:
# Text(0, 0.5, ' ')

# %% [markdown]
# ## **2.2** **Base de datos Colombiana**

# %% [markdown]
# ## **3.** ***Manos a la obra***

# %% [markdown]
# **1.** Ingresa al siguiente repositorio: https://github.com/fivethirtyeight/data/blob/master/college-majors/women-stem.csv

# %% [markdown]
# **2.** Carga los datos **women-stem.csv** a través del Url e imprime el resultado en pantalla
#
# **output:** tu resultado debería lucir así

# %%
# Out:
#     Rank  Major_code  ... ShareWomen  Median
# 0      1        2419  ...   0.120564  110000
# 1      2        2416  ...   0.101852   75000
# 2      3        2415  ...   0.153037   73000
# 3      4        2417  ...   0.107313   70000
# 4      5        2418  ...   0.144967   65000
# ..   ...         ...  ...        ...     ...
# 71    72        3604  ...   0.576360   33000
# 72    73        6109  ...   0.721866   33000
# 73    74        6100  ...   0.774577   32400
# 74    75        6102  ...   0.967998   28000
# 75    76        3609  ...   0.637293   26000
#
# [76 rows x 9 columns]

# %% [markdown]
# Para seleccionar los datos específicos de una columna podemos utilizar el siguiente comando **data['columna']**, donde **data** es el dataset y **columna** es el nombre de la columna que deseamos filtar

# %% [markdown]
# **3.** Selecciona los datos de la columna **Major_category**
#
# **output:** Tu resultado debería lucir así

# %%
# Out:
# 0                Engineering
# 1                Engineering
# 2                Engineering
# 3                Engineering
# 4                Engineering
#                ...
# 71    Biology & Life Science
# 72                    Health
# 73                    Health
# 74                    Health
# 75    Biology & Life Science
# Name: Major_category, Length: 76, dtype: object

# %% [markdown]
# ***Pandas*** también tiene diferentes funciones, una de ella es **tolist()**, esta función nos permite hacer una lista a partir de ciertos valores

# %% [markdown]
# **4.** Realiza una lista de las categorias que filtraste en el ítem anterior
#
# **output:** Tu resultado debería lucir así

# %%
# Out:
# ['Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Physical Sciences',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Computers & Mathematics',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Engineering',
#  'Health',
#  'Engineering',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Computers & Mathematics',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Computers & Mathematics',
#  'Computers & Mathematics',
#  'Biology & Life Science',
#  'Health',
#  'Physical Sciences',
#  'Engineering',
#  'Computers & Mathematics',
#  'Health',
#  'Computers & Mathematics',
#  'Biology & Life Science',
#  'Engineering',
#  'Engineering',
#  'Physical Sciences',
#  'Engineering',
# ...

# %% [markdown]
# Como puedes notar existen muchos datos repetidos en esta lista, utilizando la función **set()** puedes resolver este problema, esta función te creará un set donde los elementos no se repetirán, tal como se ve en el ejemplo

# %%
set(data['Major_category'].tolist())
# Out:
# {'Biology & Life Science',
#  'Computers & Mathematics',
#  'Engineering',
#  'Health',
#  'Physical Sciences'}

# %% [markdown]
# **5.** Realiza una lista de los elementos de la columna **Major**
#
# **output:** Tu resultado debería lucir así

# %%
# Out:
# ['PETROLEUM ENGINEERING',
#  'MINING AND MINERAL ENGINEERING',
#  'METALLURGICAL ENGINEERING',
#  'NAVAL ARCHITECTURE AND MARINE ENGINEERING',
#  'NUCLEAR ENGINEERING',
#  'CHEMICAL ENGINEERING',
#  'ASTRONOMY AND ASTROPHYSICS',
#  'MECHANICAL ENGINEERING',
#  'AEROSPACE ENGINEERING',
#  'ELECTRICAL ENGINEERING',
#  'COMPUTER ENGINEERING',
#  'MATERIALS SCIENCE',
#  'BIOMEDICAL ENGINEERING',
#  'ENGINEERING MECHANICS PHYSICS AND SCIENCE',
#  'BIOLOGICAL ENGINEERING',
#  'INDUSTRIAL AND MANUFACTURING ENGINEERING',
#  'GENERAL ENGINEERING',
#  'ARCHITECTURAL ENGINEERING',
#  'COMPUTER SCIENCE',
#  'ELECTRICAL ENGINEERING TECHNOLOGY',
#  'MATERIALS ENGINEERING AND MATERIALS SCIENCE',
#  'MISCELLANEOUS ENGINEERING',
#  'CIVIL ENGINEERING',
#  'ENGINEERING TECHNOLOGIES',
#  'GEOLOGICAL AND GEOPHYSICAL ENGINEERING',
#  'ENVIRONMENTAL ENGINEERING',
#  'NURSING',
#  'INDUSTRIAL PRODUCTION TECHNOLOGIES',
#  'NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES',
# ...

# %% [markdown]
# Selecciona de una las áreas, a la que te dediques o te interese conocer **ej PHYSICS(Física)**. ***Pandas*** es una herramienta muy poderosa y te permite con pocos comando realizar filtros, por ejemplo vamos a ver los resultados del dataset para el área de física.

# %%
data_fisica=data[data['Major']=='PHYSICS']
data_fisica
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc9695df7d14> in <module>()
# ----> 1 data_fisica=data[data['Major']=='PHYSICS']
#       2 data_fisica
#
# NameError: name 'data' is not defined

# %% [markdown]
# Ahora podemos graficar, aplicando estos filtros también.

# %%
data_fisica.plot.barh(x='Major',y=["ShareWomen"])

# %% [markdown]
# **6.** Grafica el resultado de las columnas **"Women"** y **"Men"**.
#
# **output:** Tu resultado debería lucir así

# %% [markdown]
# # ***4. Algunos proyectos y referencias adicionales***
# ### **Científicas en cifras**
# Disponible:[Científicas en cifras](https://www.ciencia.gob.es/Secc-Servicios/Igualdad/cientificas-en-cifras.html;jsessionid=74E484B9742F8259BF04F364E3785E84)
#
# La serie estadística Científicas en cifras, elaborada por la Unidad Mujeres y Ciencia, sirve como línea base para el seguimiento del impacto de las políticas y medidas implementadas en materia de igualdad en ciencia.
#
# ### **Mujeres en ciencia Latina: Paridad de género en el siglo 21 y perspectivas para una Colombia post-conflicto**
# Disponible:[Articulo](https://www.tandfonline.com/doi/full/10.1080/25729861.2019.1621538)
#
#
# ### **Inequality in STEM**
# Disponible: [Notebook](https://www.kaggle.com/minkles/inequality-in-stem/notebook)
